# %%
#import relevant library (selenium)
from selenium.webdriver.common.by import By
from selenium import webdriver
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.ui import WebDriverWait as wait
from selenium.webdriver.support import expected_conditions as EC

# importing library for web scraping
import requests
import pandas as pd
from bs4 import BeautifulSoup as bs
import json
import time



#---scraping tech stock name for selenium---

# starting scraping process
url =  "https://en.wikipedia.org/wiki/Big_Tech"
response = requests.get(url)
soup = bs(response.text, "html.parser")

#finding all table on the website to scrape with the class listed below
table = soup.find_all("table", {"class": "wikitable sortable mw-collapsible floatright"})

# Read the html table and put the dataframe in a list
df = pd.read_html(str(table))


# Getting the 1st DF named 'Big Five tech companies'
tb1 =df[0]
# Getting the 2nd DF named 'Smaller U.S. Big Tech companies'
tb2 =df[1]
DF1 = pd.concat([tb1,tb2])

company_Name = DF1["Company"].tolist()
print(company_Name)
# Out:
# ['Alphabet', 'Amazon', 'Apple', 'Meta', 'Microsoft', 'IBM', 'Tesla', 'Oracle', 'Netflix', 'Nvidia', 'Salesforce', 'Adobe']

# %%
#---selenium part---

#Create a Chrome web driver
driver = webdriver.Chrome()
actions = ActionChains(driver)

#Navigate to website
driver.get("https://finance.yahoo.com/")

# search for the full popup and closing it
ads_search = driver.find_element(By.XPATH, '//*[@id="overlay-module"]')
close_button = driver.find_element(By.XPATH, '//*[@id="myLightboxContainer"]/button')
close_button.click()

#Insantiating list
Stock_Name = []
previousClose = []
openingPrice = []
dailyPriceRange = []
week52PriceRange = []
volume = []
marketCap = []
beta = []
dividend = []
nextDividendDate = []



for stocks in company_Name:
    #Locate the search bar and send the keyword to it
    search = driver.find_element(By.ID, 'yfin-usr-qry')
    search.send_keys(stocks)

    #Find the search button on the html and click search
    search_button = driver.find_element(By.ID, 'header-desktop-search-button')
    search_button.click()
    time.sleep(5)


    #Finding all value in the table
    table_items = wait(driver, 10).until(EC.presence_of_all_elements_located((By.XPATH, '//*[@id="quote-summary"]')))

    for item in table_items:
    #Getting previous close
        PC = item.find_element(By.XPATH, '//*[@id="quote-summary"]/div[1]/table/tbody/tr[1]/td[2]')
        value1 = PC.text
        previousClose.append(float(value1))

    #Getting Open
        OP = item.find_element(By.XPATH,'//*[@id="quote-summary"]/div[1]/table/tbody/tr[2]/td[2]')
        value2 = OP.text
        openingPrice.append(float(value2))

    #Getting days range
        DR = item.find_element(By.XPATH,'//*[@id="quote-summary"]/div[1]/table/tbody/tr[5]/td[2]')
        value3 = DR.text
        dailyPriceRange.append(str(value3))

    #Getting 52 week range
        WR52 = item.find_element(By.XPATH,'//*[@id="quote-summary"]/div[1]/table/tbody/tr[6]/td[2]')
        value4 = WR52.text
        week52PriceRange.append(str(value4))

    #Getting volume
        V = item.find_element(By.XPATH,'//*[@id="quote-summary"]/div[1]/table/tbody/tr[7]/td[2]/fin-streamer')
        value5 = V.text
        volume.append(str(value5))

    #Getting market cap
        MC = item.find_element(By.XPATH,'//*[@id="quote-summary"]/div[2]/table/tbody/tr[1]/td[2]')
        value6 = MC.text
        marketCap.append(str(value6))

    #Getting Beta(closer to 1 are generally good, less risk)
        B = item.find_element(By.XPATH,'//*[@id="quote-summary"]/div[2]/table/tbody/tr[2]/td[2]')
        value7 = B.text
        beta.append(float(value7))

    #Getting dividend yield 
        DDD = item.find_element(By.XPATH,'//*[@id="quote-summary"]/div[2]/table/tbody/tr[6]/td[2]')
        value8 = DDD.text
        dividend.append(str(value8))

    #Getting next ex dividend date
        NDD = item.find_element(By.XPATH,'//*[@id="quote-summary"]/div[2]/table/tbody/tr[7]/td[2]')
        value9 = NDD.text
        nextDividendDate.append(str(value9))
        
    # Adding stock name to list
    Stock_Name.append(stocks)
        
    # printing the list result
    print(f'pc = {previousClose}')
    print(f'op = {openingPrice}')
    print(f'daily price range = {dailyPriceRange}')
    print(f'52 week = {week52PriceRange}')
    print(f'Volume = {volume}')
    print(f'market cap = {marketCap}')
    print(f'Beta = {beta}')
    print(f'Dividend = {dividend}')
    print(f'next Dividend Date = {nextDividendDate}')


    # clearing search box 
    driver.find_element(By.ID, 'yfin-usr-qry').clear()

    # wait 5 sec
    time.sleep(5)

    # waiting 5 seconds for the page to load
    driver.implicitly_wait(5)

driver.quit()
# Out:
# pc = [131.85]
# op = [132.15]
# daily price range = ['132.07 - 135.36']
# 52 week = ['83.45 - 139.93']
# Volume = ['19,183,338']
# market cap = ['1.697T']
# Beta = [1.06]
# Dividend = ['N/A (N/A)']
# next Dividend Date = ['N/A']
# pc = [131.85, 127.12]
# op = [132.15, 127.28]
# daily price range = ['132.07 - 135.36', '126.54 - 130.47']
# 52 week = ['83.45 - 139.93', '81.43 - 145.86']
# Volume = ['19,183,338', '45,443,625']
# market cap = ['1.697T', '1.336T']
# Beta = [1.06, 1.24]
# Dividend = ['N/A (N/A)', 'N/A (N/A)']
# next Dividend Date = ['N/A', 'N/A']
# pc = [131.85, 127.12, 171.21]
# op = [132.15, 127.28, 171.22]
# daily price range = ['132.07 - 135.36', '126.54 - 130.47', '171.00 - 174.30']
# 52 week = ['83.45 - 139.93', '81.43 - 145.86', '124.17 - 198.23']
# Volume = ['19,183,338', '45,443,625', '50,897,710']
# market cap = ['1.697T', '1.336T', '2.716T']
# Beta = [1.06, 1.24, 1.27]
# Dividend = ['N/A (N/A)', 'N/A (N/A)', '0.96 (0.56%)']
# next Dividend Date = ['N/A', 'N/A', 'Aug 11, 2023']
# pc = [131.85, 127.12, 171.21, 300.21]
# op = [132.15, 127.28, 171.22, 302.74]
# daily price range = ['132.07 - 135.36', '126.54 - 130.47', '171.00 - 174.30', '301.63 - 307.18']
# 52 week = ['83.45 - 139.93', '81.43 - 145.86', '124.17 - 198.23', '88.09 - 326.20']
# Volume = ['19,183,338', '45,443,625', '50,897,710', '15,799,112']
# market cap = ['1.697T', '1.336T', '2.716T', '789.497B']
# Beta = [1.06, 1.24, 1.27, 1.23]
# Dividend = ['N/A (N/A)', 'N/A (N/A)', '0.96 (0.56%)', 'N/A (N/A)']
# next Dividend Date = ['N/A', 'N/A', 'Aug 11, 2023', 'N/A']
# pc = [131.85, 127.12, 171.21, 300.21, 315.75]
# op = [132.15, 127.28, 171.22, 302.74, 316.28]
# daily price range = ['132.07 - 135.36', '126.54 - 130.47', '171.00 - 174.30', '301.63 - 307.18', '315.18 - 321.88']
# 52 week = ['83.45 - 139.93', '81.43 - 145.86', '124.17 - 198.23', '88.09 - 326.20', '213.43 - 366.78']
# Volume = ['19,183,338', '45,443,625', '50,897,710', '15,799,112', '19,901,001']
# market cap = ['1.697T', '1.336T', '2.716T', '789.497B', '2.391T']
# Beta = [1.06, 1.24, 1.27, 1.23, 0.9]
# Dividend = ['N/A (N/A)', 'N/A (N/A)', '0.96 (0.56%)', 'N/A (N/A)', '3.00 (0.95%)']
# next Dividend Date = ['N/A', 'N/A', 'Aug 11, 2023', 'N/A', 'Nov 15, 2023']
# pc = [131.85, 127.12, 171.21, 300.21, 315.75, 140.3]
# op = [132.15, 127.28, 171.22, 302.74, 316.28, 140.04]
# daily price range = ['132.07 - 135.36', '126.54 - 130.47', '171.00 - 174.30', '301.63 - 307.18', '315.18 - 321.88', '139.90 - 141.41']
# 52 week = ['83.45 - 139.93', '81.43 - 145.86', '124.17 - 198.23', '88.09 - 326.20', '213.43 - 366.78', '115.55 - 153.21']
# Volume = ['19,183,338', '45,443,625', '50,897,710', '15,799,112', '19,901,001', '3,275,143']
# market cap = ['1.697T', '1.336T', '2.716T', '789.497B', '2.391T', '128.27B']
# Beta = [1.06, 1.24, 1.27, 1.23, 0.9, 0.85]
# Dividend = ['N/A (N/A)', 'N/A (N/A)', '0.96 (0.56%)', 'N/A (N/A)', '3.00 (0.95%)', '6.64 (4.73%)']
# next Dividend Date = ['N/A', 'N/A', 'Aug 11, 2023', 'N/A', 'Nov 15, 2023', 'Aug 09, 2023']
# pc = [131.85, 127.12, 171.21, 300.21, 315.75, 140.3, 250.22]
# op = [132.15, 127.28, 171.22, 302.74, 316.28, 140.04, 244.81]
# daily price range = ['132.07 - 135.36', '126.54 - 130.47', '171.00 - 174.30', '301.63 - 307.18', '315.18 - 321.88', '139.90 - 141.41', '242.62 - 254.28']
# 52 week = ['83.45 - 139.93', '81.43 - 145.86', '124.17 - 198.23', '88.09 - 326.20', '213.43 - 366.78', '115.55 - 153.21', '101.81 - 299.29']
# Volume = ['19,183,338', '45,443,625', '50,897,710', '15,799,112', '19,901,001', '3,275,143', '123,451,199']
# market cap = ['1.697T', '1.336T', '2.716T', '789.497B', '2.391T', '128.27B', '798.576B']
# Beta = [1.06, 1.24, 1.27, 1.23, 0.9, 0.85, 2.09]
# Dividend = ['N/A (N/A)', 'N/A (N/A)', '0.96 (0.56%)', 'N/A (N/A)', '3.00 (0.95%)', '6.64 (4.73%)', 'N/A (N/A)']
# next Dividend Date = ['N/A', 'N/A', 'Aug 11, 2023', 'N/A', 'Nov 15, 2023', 'Aug 09, 2023', 'N/A']
# pc = [131.85, 127.12, 171.21, 300.21, 315.75, 140.3, 250.22, 105.92]
# op = [132.15, 127.28, 171.22, 302.74, 316.28, 140.04, 244.81, 105.81]
# daily price range = ['132.07 - 135.36', '126.54 - 130.47', '171.00 - 174.30', '301.63 - 307.18', '315.18 - 321.88', '139.90 - 141.41', '242.62 - 254.28', '105.29 - 106.73']
# 52 week = ['83.45 - 139.93', '81.43 - 145.86', '124.17 - 198.23', '88.09 - 326.20', '213.43 - 366.78', '115.55 - 153.21', '101.81 - 299.29', '60.81 - 127.54']
# Volume = ['19,183,338', '45,443,625', '50,897,710', '15,799,112', '19,901,001', '3,275,143', '123,451,199', '5,960,072']
# market cap = ['1.697T', '1.336T', '2.716T', '789.497B', '2.391T', '128.27B', '798.576B', '292.319B']
# Beta = [1.06, 1.24, 1.27, 1.23, 0.9, 0.85, 2.09, 0.99]
# Dividend = ['N/A (N/A)', 'N/A (N/A)', '0.96 (0.56%)', 'N/A (N/A)', '3.00 (0.95%)', '6.64 (4.73%)', 'N/A (N/A)', '1.60 (1.51%)']
# next Dividend Date = ['N/A', 'N/A', 'Aug 11, 2023', 'N/A', 'Nov 15, 2023', 'Aug 09, 2023', 'N/A', 'Oct 11, 2023']
# pc = [131.85, 127.12, 171.21, 300.21, 315.75, 140.3, 250.22, 105.92, 377.6]
# op = [132.15, 127.28, 171.22, 302.74, 316.28, 140.04, 244.81, 105.81, 377.48]
# daily price range = ['132.07 - 135.36', '126.54 - 130.47', '171.00 - 174.30', '301.63 - 307.18', '315.18 - 321.88', '139.90 - 141.41', '242.62 - 254.28', '105.29 - 106.73', '376.81 - 384.81']
# 52 week = ['83.45 - 139.93', '81.43 - 145.86', '124.17 - 198.23', '88.09 - 326.20', '213.43 - 366.78', '115.55 - 153.21', '101.81 - 299.29', '60.81 - 127.54', '211.73 - 485.00']
# Volume = ['19,183,338', '45,443,625', '50,897,710', '15,799,112', '19,901,001', '3,275,143', '123,451,199', '5,960,072', '3,095,579']
# market cap = ['1.697T', '1.336T', '2.716T', '789.497B', '2.391T', '128.27B', '798.576B', '292.319B', '168.542B']
# Beta = [1.06, 1.24, 1.27, 1.23, 0.9, 0.85, 2.09, 0.99, 1.29]
# Dividend = ['N/A (N/A)', 'N/A (N/A)', '0.96 (0.56%)', 'N/A (N/A)', '3.00 (0.95%)', '6.64 (4.73%)', 'N/A (N/A)', '1.60 (1.51%)', 'N/A (N/A)']
# next Dividend Date = ['N/A', 'N/A', 'Aug 11, 2023', 'N/A', 'Nov 15, 2023', 'Aug 09, 2023', 'N/A', 'Oct 11, 2023', 'N/A']
# pc = [131.85, 127.12, 171.21, 300.21, 315.75, 140.3, 250.22, 105.92, 377.6, 434.99]
# op = [132.15, 127.28, 171.22, 302.74, 316.28, 140.04, 244.81, 105.81, 377.48, 440.3]
# daily price range = ['132.07 - 135.36', '126.54 - 130.47', '171.00 - 174.30', '301.63 - 307.18', '315.18 - 321.88', '139.90 - 141.41', '242.62 - 254.28', '105.29 - 106.73', '376.81 - 384.81', '438.61 - 451.75']
# 52 week = ['83.45 - 139.93', '81.43 - 145.86', '124.17 - 198.23', '88.09 - 326.20', '213.43 - 366.78', '115.55 - 153.21', '101.81 - 299.29', '60.81 - 127.54', '211.73 - 485.00', '108.13 - 502.66']
# Volume = ['19,183,338', '45,443,625', '50,897,710', '15,799,112', '19,901,001', '3,275,143', '123,451,199', '5,960,072', '3,095,579', '42,452,788']
# market cap = ['1.697T', '1.336T', '2.716T', '789.497B', '2.391T', '128.27B', '798.576B', '292.319B', '168.542B', '1.106T']
# Beta = [1.06, 1.24, 1.27, 1.23, 0.9, 0.85, 2.09, 0.99, 1.29, 1.74]
# Dividend = ['N/A (N/A)', 'N/A (N/A)', '0.96 (0.56%)', 'N/A (N/A)', '3.00 (0.95%)', '6.64 (4.73%)', 'N/A (N/A)', '1.60 (1.51%)', 'N/A (N/A)', '0.16 (0.04%)']
# next Dividend Date = ['N/A', 'N/A', 'Aug 11, 2023', 'N/A', 'Nov 15, 2023', 'Aug 09, 2023', 'N/A', 'Oct 11, 2023', 'N/A', 'Sep 06, 2023']
# pc = [131.85, 127.12, 171.21, 300.21, 315.75, 140.3, 250.22, 105.92, 377.6, 434.99, 202.78]
# op = [132.15, 127.28, 171.22, 302.74, 316.28, 140.04, 244.81, 105.81, 377.48, 440.3, 200.8]
# daily price range = ['132.07 - 135.36', '126.54 - 130.47', '171.00 - 174.30', '301.63 - 307.18', '315.18 - 321.88', '139.90 - 141.41', '242.62 - 254.28', '105.29 - 106.73', '376.81 - 384.81', '438.61 - 451.75', '200.52 - 205.11']
# 52 week = ['83.45 - 139.93', '81.43 - 145.86', '124.17 - 198.23', '88.09 - 326.20', '213.43 - 366.78', '115.55 - 153.21', '101.81 - 299.29', '60.81 - 127.54', '211.73 - 485.00', '108.13 - 502.66', '126.34 - 238.22']
# Volume = ['19,183,338', '45,443,625', '50,897,710', '15,799,112', '19,901,001', '3,275,143', '123,451,199', '5,960,072', '3,095,579', '42,452,788', '3,728,518']
# market cap = ['1.697T', '1.336T', '2.716T', '789.497B', '2.391T', '128.27B', '798.576B', '292.319B', '168.542B', '1.106T', '198.21B']
# Beta = [1.06, 1.24, 1.27, 1.23, 0.9, 0.85, 2.09, 0.99, 1.29, 1.74, 1.19]
# Dividend = ['N/A (N/A)', 'N/A (N/A)', '0.96 (0.56%)', 'N/A (N/A)', '3.00 (0.95%)', '6.64 (4.73%)', 'N/A (N/A)', '1.60 (1.51%)', 'N/A (N/A)', '0.16 (0.04%)', 'N/A (N/A)']
# next Dividend Date = ['N/A', 'N/A', 'Aug 11, 2023', 'N/A', 'Nov 15, 2023', 'Aug 09, 2023', 'N/A', 'Oct 11, 2023', 'N/A', 'Sep 06, 2023', 'N/A']
# pc = [131.85, 127.12, 171.21, 300.21, 315.75, 140.3, 250.22, 105.92, 377.6, 434.99, 202.78, 509.9]
# op = [132.15, 127.28, 171.22, 302.74, 316.28, 140.04, 244.81, 105.81, 377.48, 440.3, 200.8, 508.24]
# daily price range = ['132.07 - 135.36', '126.54 - 130.47', '171.00 - 174.30', '301.63 - 307.18', '315.18 - 321.88', '139.90 - 141.41', '242.62 - 254.28', '105.29 - 106.73', '376.81 - 384.81', '438.61 - 451.75', '200.52 - 205.11', '508.24 - 522.41']
# 52 week = ['83.45 - 139.93', '81.43 - 145.86', '124.17 - 198.23', '88.09 - 326.20', '213.43 - 366.78', '115.55 - 153.21', '101.81 - 299.29', '60.81 - 127.54', '211.73 - 485.00', '108.13 - 502.66', '126.34 - 238.22', '276.60 - 570.24']
# Volume = ['19,183,338', '45,443,625', '50,897,710', '15,799,112', '19,901,001', '3,275,143', '123,451,199', '5,960,072', '3,095,579', '42,452,788', '3,728,518', '2,303,080']
# market cap = ['1.697T', '1.336T', '2.716T', '789.497B', '2.391T', '128.27B', '798.576B', '292.319B', '168.542B', '1.106T', '198.21B', '237.27B']
# Beta = [1.06, 1.24, 1.27, 1.23, 0.9, 0.85, 2.09, 0.99, 1.29, 1.74, 1.19, 1.33]
# Dividend = ['N/A (N/A)', 'N/A (N/A)', '0.96 (0.56%)', 'N/A (N/A)', '3.00 (0.95%)', '6.64 (4.73%)', 'N/A (N/A)', '1.60 (1.51%)', 'N/A (N/A)', '0.16 (0.04%)', 'N/A (N/A)', 'N/A (N/A)']
# next Dividend Date = ['N/A', 'N/A', 'Aug 11, 2023', 'N/A', 'Nov 15, 2023', 'Aug 09, 2023', 'N/A', 'Oct 11, 2023', 'N/A', 'Sep 06, 2023', 'N/A', 'Mar 24, 2005']

# %%
# making the data frame
stockinfo_DF = pd.DataFrame({
    
    "Stocks (Ticker)": Stock_Name,
    "Previous Close": previousClose,
    "Opening Price": openingPrice,
    "Daily Price Range" : dailyPriceRange,
    "Week 52 Price Range" : week52PriceRange,  
    "Volume"  : volume,
    "Market Cap" : marketCap,
    "Beta": beta,
    "Dividend this month" : dividend,
    "Next Dividend Date" : nextDividendDate 
    
})


stockinfo_DF
# Out:
#    Stocks (Ticker)  Previous Close  Opening Price Daily Price Range  \
# 0         Alphabet          131.85         132.15   132.07 - 135.36
# 1           Amazon          127.12         127.28   126.54 - 130.47
# 2            Apple          171.21         171.22   171.00 - 174.30
# 3             Meta          300.21         302.74   301.63 - 307.18
# 4        Microsoft          315.75         316.28   315.18 - 321.88
# 5              IBM          140.30         140.04   139.90 - 141.41
# 6            Tesla          250.22         244.81   242.62 - 254.28
# 7           Oracle          105.92         105.81   105.29 - 106.73
# 8          Netflix          377.60         377.48   376.81 - 384.81
# 9           Nvidia          434.99         440.30   438.61 - 451.75
# 10      Salesforce          202.78         200.80   200.52 - 205.11
# 11           Adobe          509.90         508.24   508.24 - 522.41
#
#    Week 52 Price Range       Volume Market Cap  Beta Dividend this month  \
# 0       83.45 - 139.93   19,183,338     1.697T  1.06           N/A (N/A)
# 1       81.43 - 145.86   45,443,625     1.336T  1.24           N/A (N/A)
# 2      124.17 - 198.23   50,897,710     2.716T  1.27        0.96 (0.56%)
# 3       88.09 - 326.20   15,799,112   789.497B  1.23           N/A (N/A)
# 4      213.43 - 366.78   19,901,001     2.391T  0.90        3.00 (0.95%)
# 5      115.55 - 153.21    3,275,143    128.27B  0.85        6.64 (4.73%)
# 6      101.81 - 299.29  123,451,199   798.576B  2.09           N/A (N/A)
# 7       60.81 - 127.54    5,960,072   292.319B  0.99        1.60 (1.51%)
# 8      211.73 - 485.00    3,095,579   168.542B  1.29           N/A (N/A)
# 9      108.13 - 502.66   42,452,788     1.106T  1.74        0.16 (0.04%)
# 10     126.34 - 238.22    3,728,518    198.21B  1.19           N/A (N/A)
# 11     276.60 - 570.24    2,303,080    237.27B  1.33           N/A (N/A)
#
#    Next Dividend Date
# 0                 N/A
# 1                 N/A
# 2        Aug 11, 2023
# 3                 N/A
# 4        Nov 15, 2023
# 5        Aug 09, 2023
# 6                 N/A
# 7        Oct 11, 2023
# 8                 N/A
# 9        Sep 06, 2023
# 10                N/A
# 11       Mar 24, 2005
